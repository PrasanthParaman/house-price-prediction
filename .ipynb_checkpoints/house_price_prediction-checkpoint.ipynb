# %% [markdown]
# # Project Objective:
# Regression problem aimed to predict the median house prices for district blocks in California. The dataset used is a publicly available kaggle dataset. https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import numpy as np
import seaborn as sns
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
def load_data(file_path):
    return pd.read_csv(file_path)

# %%
housing = load_data('data/housing.csv')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# <li> There is a total of 20k records which is fairly a small dataset in terms of machine learning standards. </li>
# <li> There are some missing records in total_bedrooms feature </li>
# <li> There are a total of 9 numerical features </li>
# <li> There is 1 categorical feature</li>

# %% [markdown]
# ### Todo data cleaning:
# <li> Handle missing records in total bedrooms </li>

# %% [markdown]
# ### Exploration of numerical features

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# <li> The median income is not in absolute number. It is scaled. </li>

# %%
housing.hist(bins=50, figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# <li> The median_income is scaled and the minimum and maximum is scaled at 0.5 and and 15. We could assume that these numbers are in tens of thousands. </li>
# <li> Looks like both housing_median_age and median_house_value are capped as well. </li>
# <li> The numerical features range are too diverse. For a learning algorithm to work better, the features range must be in comparable range </li>
# <li> Many featuers are right skewed. This might make it hard for the machine learning algorithms to detect patterns. </li>

# %% [markdown]
# ### Todo data cleaning:
# <li> Handle missing records in total bedrooms </li>
# <li> Feature scale numerical features</li>
# <li> Transform numerical features total_rooms, total_bedrooms, population and households to have a more bell shaped like histogram </li>

# %% [markdown]
# ### Exploration of categorical features

# %%
housing['ocean_proximity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ocean_proximity'>

# %% [markdown]
# ### Train-CV-Test Split
# Let's split the dataset into train, cross-validation and test splits before doing any data transformation and further exploration.

# %%
training, validation_test = train_test_split(housing, test_size=0.3, random_state=42)
validation, testing = train_test_split(validation_test, test_size=0.5, random_state=42)

training.shape, validation.shape, testing.shape
# Out:
# ((14448, 10), (3096, 10), (3096, 10))

# %%
plt.scatter(training['longitude'], training['latitude'], alpha=0.1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()

# %% [markdown]
# The above plot clearly shows high density areas such as the Bay Area and San Diego.

# %%
# Normalize the median_house_value for color mapping
norm = Normalize(vmin=housing['median_house_value'].min(), vmax=housing['median_house_value'].max())
cmap = cm.jet  # Colormap for color mapping

# Plot the scatter plot with color mapping and size based on population
fig, ax = plt.subplots()
sc = ax.scatter(housing['longitude'], housing['latitude'], alpha=0.3, s=housing['population']/100,
                c=housing['median_house_value'], cmap=cmap, norm=norm)
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Create a colorbar using the ScalarMappable object
cbar_ax = fig.add_axes([0.95, 0.1, 0.03, 0.8])  # [left, bottom, width, height]
cbar = plt.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), cax=cbar_ax)
cbar.set_label('Median House Value')

# Create a legend for the marker sizes
plt.legend(['Population'])

plt.show()

# %% [markdown]
# <li> In the above plot, the radius of each circle represents the population of the district </li>
# <li> The color distinguishes the median house value </li>
# <li> House close to the ocean have high prices and is very much related to the population. </li>

# %% [markdown]
# ### Todo data cleaning:
# <li> Handle missing records in total bedrooms </li>
# <li> Feature scale numerical features</li>
# <li> Transform numerical features total_rooms, total_bedrooms, population and households to have a more bell shaped like histogram </li>
# <li> Perform clustering on the data and add distances to the centre of each cluster as new features </li>

# %% [markdown]
# ### Correlation Analysis

# %%
numerical_features = training.select_dtypes(include=['int64', 'float64']).columns

# %%
numerical_features
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
corr_matrix = training[numerical_features].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Median house value has a positive correlation with median_incoem, total_rooms, housing_median_age(surprisingly a positive correlation), households

# %% [markdown]
# ### Todo data cleaning:
# <li> Handle missing records in total bedrooms </li>
# <li> Feature scale numerical features</li>
# <li> Transform numerical features total_rooms, total_bedrooms, population and households to have a more bell shaped like histogram </li>
# <li> Perform clustering on the data and add distances to the centre of each cluster as new features </li>
# <li> Try performing PCA on the data to handle multi-collinearity observed </li>

# %%
training.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.1)
plt.axhline(y=350000, color='red', linestyle='--', linewidth=0.51)
plt.axhline(y=500000, color='red', linestyle='--', linewidth=0.51)
plt.axhline(y=450000, color='red', linestyle='--', linewidth=0.51)

# %% [markdown]
# ### Todo data cleaning:
# <li> Handle missing records in total bedrooms </li>
# <li> Feature scale numerical features</li>
# <li> Transform numerical features total_rooms, total_bedrooms, population and households to have a more bell shaped like histogram </li>
# <li> Perform clustering on the data and add distances to the centre of each cluster as new features </li>
# <li> Try performing PCA on the data to handle multi-collinearity observed </li>
# <li> There seems to be few apparent lines at around 500k, 450k, 350k. Since there is high correlation between median_income and median_house_value we should remove these values from dataset to prevent the model from replicating this pattern </li>

# %% [markdown]
# ### Feature Engineering

# %%
training.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Let's try combinig attributes and see how they are correlated with the house value
class CombinedAttribuesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, room_index=3, bedroom_index=4, population_index=5, household_index=6):
        self.room_index = room_index
        self.bedroom_index = bedroom_index
        self.population_index = population_index
        self.household_index = household_index
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        rooms_per_household = X[:, self.room_index]/X[:, self.household_index]
        population_per_household = X[:, self.population_index]/X[:, self.household_index]
        return np.c_[X, rooms_per_household, population_per_household]

# %%
class LogTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns_to_log_transform=[]):
        self.columns_to_log_transform = columns_to_log_transform
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        for each in self.columns_to_log_transform:
            X[:, each] = np.log1p(X[:, each])
        return X

# %%
# testing the log_transformer
X = np.random.uniform(1, 10000, (100, 1))
X_orig = X.copy()
log_transformer = LogTransformer(columns_to_log_transform=[0])
log_X = log_transformer.transform(X)
fig, ax = plt.subplots(1,2)
ax[0].hist(X_orig, bins=20, color='blue', alpha=0.7)
ax[0].set_title('Original Matrix')

# Histogram of the log-transformed matrix
ax[1].hist(log_X, bins=10, color='green', alpha=0.7)
ax[1].set_title('Log-Transformed Matrix')
# Out:
# Text(0.5, 1.0, 'Log-Transformed Matrix')

# %%
# let's split all the datasets into corresponding features and labels
training_X = training.drop(['median_house_value'], axis=1)
training_y = training['median_house_value'].values
validation_X = validation.drop(['median_house_value'], axis=1)
validation_y = validation['median_house_value'].values
testing_X = testing.drop(['median_house_value'], axis=1)
testing_y = testing['median_house_value'].values

# %%
numerical_features = list(training_X.select_dtypes(include=['int64', 'float64']).columns)
categorical_features = ['ocean_proximity']

# %% [markdown]
# ### Data cleaning resolutions:
# <li> Handle missing records in total bedrooms -- <b> Impute with median </b> </li>
# <li> Feature scale numerical features -- <b> Feature scale with standardization </b></li>
# <li> Transform numerical features total_rooms, total_bedrooms, population and households to have a more bell shaped like histogram -- <b> Log transform them </b> </li>
# <li> Encode categorical feature ocean_proximity -- <b> Use Ordinal Encoder </b> </li>
# <li> Perform clustering on the data and add distances to the centre of each cluster as new features </li>
# <li> Try performing PCA on the data to handle multi-collinearity observed </li>

# %%
# let's build a pipeline to handle transformation on numerical features and then build a full transformer
# to handle both numerical and categorical features
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attributes_adder', CombinedAttribuesAdder()),
    ('log_transformer',LogTransformer(columns_to_log_transform=[3,4,5,6])),
    ('std_scaler', StandardScaler())
])

full_pipeline = ColumnTransformer([
    ("num", numerical_pipeline, numerical_features),
    ("cat", OneHotEncoder(), categorical_features)
])

# %%
training_X_prepared = full_pipeline.fit_transform(training_X)

# %%
training_X_prepared.shape
# Out:
# (14448, 15)

# %% [markdown]
# ### Linear Regression Model

# %%
lin_reg = LinearRegression()
lin_reg.fit(training_X_prepared, training_y)
# Out:
# LinearRegression()

# %%
housing_predictions = lin_reg.predict(full_pipeline.transform(validation_X))

# %%
mape = mean_absolute_percentage_error(validation_y, housing_predictions)
mse = mean_squared_error(validation_y, housing_predictions)
print(f'Mean Absolution % Error: {mape}, Root Mean Squared Error: {np.sqrt(mse)}')
# Out:
# Mean Absolution % Error: 0.2933373411928861, Root Mean Squared Error: 68333.09378092819

# %% [markdown]
# ### Random Forest Regressor

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(training_X_prepared, training_y)
predictions_rf = rf_regressor.predict(full_pipeline.transform(validation_X))

# %%
mape = mean_absolute_percentage_error(validation_y, predictions_rf)
mse = mean_squared_error(validation_y, predictions_rf)
print(f'Mean Absolution % Error: {mape}, Root Mean Squared Error: {np.sqrt(mse)}')
# Out:
# Mean Absolution % Error: 0.18349818831093592, Root Mean Squared Error: 51053.79332273024

# %% [markdown]
# ### XGB Regressor

# %%
xgb_regressor = XGBRegressor(objective='reg:squarederror')
xgb_regressor.fit(training_X_prepared, training_y)
predictons_xgb = xgb_regressor.predict(full_pipeline.transform(validation_X))

# %%
mape = mean_absolute_percentage_error(validation_y, predictons_xgb)
mse = mean_squared_error(validation_y, predictons_xgb)
print(f'Mean Absolution % Error: {mape}, Root Mean Squared Error: {np.sqrt(mse)}')
# Out:
# Mean Absolution % Error: 0.1729115310024705, Root Mean Squared Error: 46992.52641371898

# %% [markdown]
# ### Based on all the three models, XGBRegressor works best with the lowest RMSE.

# %%
# let's try tuning the hyper parameter of XGBoostRegressor to improve its performance
param_grid = {
    'xgb__n_estimators': [100, 200, 300, 400, 500],
    'xgb__max_depth': [3,4,5,6,7],
    'xgb__learning_rate': [0.01, 0.05, 0.1],
    'xgb__subsample': [0.7, 0.8, 0.9],
    'xgb__colsample_bytree': [0.7, 0.8, 0.9]
}

# %%
pipeline_xgb = Pipeline([
    ('preprocessor', full_pipeline),
    ('xgb', XGBRegressor())
])

# %%
grid_search = GridSearchCV(pipeline_xgb, param_grid, cv=3, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)
grid_search.fit(training_X, training_y)
# Out:
# Fitting 3 folds for each of 675 candidates, totalling 2025 fits
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8; total time=   0.1s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200, xgb__subsample=0.7; total time=   0.2s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.7; total time=   0.2s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.9; total time=   0.2s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=400, xgb__subsample=0.9; total time=   0.3s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=500, xgb__subsample=0.9; total time=   0.3s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=4, xgb__n_estimators=100, xgb__subsample=0.8; total time=   0.1s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=4, xgb__n_estimators=200, xgb__subsample=0.8; total time=   0.2s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=4, xgb__n_estimators=300, xgb__subsample=0.8; total time=   0.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=4, xgb__n_estimators=400, xgb__subsample=0.8; total time=   0.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth=4, xgb__n_estimators=500, xgb__subsample=0.8; total time=   0.5s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.01, xgb__max_depth

# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.01, xgb__max_depth=7, xgb__n_estimators=500, xgb__subsample=0.9; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=400, xgb__subsample=0.9; total time=   0.3s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=500, xgb__subsample=0.8; total time=   0.4s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=4, xgb__n_estimators=100, xgb__subsample=0.9; total time=   0.1s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=4, xgb__n_estimators=200, xgb__subsample=0.8; total time=   0.2s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=4, xgb__n_estimators=300, xgb__subsample=0.8; total time=   0.3s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=4, xgb__n_estimators=400, xgb__subsample=0.7; total time=   0.5s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.05, xgb__max_depth=4, xgb__n_estimators=500, xgb__subsample=0.7; total time=   0.8s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('attributes_adder',
#                                                                                           CombinedAttribuesAdder()),
#                                                                                          ('log_transformer',
#                                                                                           LogTransformer(columns_to_log_transform=[3,
#                                                                                                                                    4,
#                                                                                                                                    5,
#                                                                                                                                    6])),
#                                                                                          ('std_scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['longitude',
#                                                                           'latitude',
#                                                                           'housing_median...
#                                                      monotone_constraints=None,
#                                                      multi_strategy=None,
#                                                      n_estimators=None,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      random_state=None, ...))]),
#              n_jobs=-1,
#              param_grid={'xgb__colsample_bytree': [0.7, 0.8, 0.9],
#                          'xgb__learning_rate': [0.01, 0.05, 0.1],
#                          'xgb__max_depth': [3, 4, 5, 6, 7],
#                          'xgb__n_estimators': [100, 200, 300, 400, 500],
#                          'xgb__subsample': [0.7, 0.8, 0.9]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
# best parameters and score
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# -2106346573.5747852

# %%
# best estimator
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('attributes_adder',
#                                                                    CombinedAttribuesAdder()),
#                                                                   ('log_transformer',
#                                                                    LogTransformer(columns_to_log_transform=[3,
#                                                                                                             4,
#                                                                                                             5,
#                                                                                                             6])),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_b...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=7, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=500, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
cv_res = grid_search.cv_results_
for score, params in zip(cv_res['mean_test_score'], cv_res['params']):
    print(np.sqrt(-score), params)
# Out:
# 79656.48370498045 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 79657.88969109663 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 79690.81123024432 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 66674.85129918225 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 66722.2879181891 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 66777.32038790964 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 61136.645423512025 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 61171.74340635294 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 61216.29839625247 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 58285.66011568546 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 58357.61808320518 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 58412.34050205228 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 56518.1067152356 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 56572.80324370388 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 56716.700409607896 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 76224.75707601065 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 76207.16075454956 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 76221.8280721565 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 62610.791114313964 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 62645.24646386125 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 62703.63012338615 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 57359.85202502647 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 57415.73952005658 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 57475.80528914422 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 54806.660408735224 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 54842.22709447154 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 54944.82950720686 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 53287.39599598922 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 53291.04852391837 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 53438.689051461064 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 73302.30927003446 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 73269.60835595314 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 73265.08145953319 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 59330.542190238295 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 59312.6950468246 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 59362.39504664757 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 54459.59375611694 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 54391.625139787284 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 54429.275453284536 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 52257.76325337481 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 52203.94768061939 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 52243.63350900476 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 50994.66880591626 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 50942.005471178956 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 51022.297146675075 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 71025.19234068673 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 70917.89355236037 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 70893.0647553577 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 56881.126869115484 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 56786.97303065813 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 56805.91432804945 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 52370.7972779242 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 52265.0763406648 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 52219.97313471341 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 50421.48227437835 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 50365.422650049055 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 50334.979009022776 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 49352.63202583719 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 49281.99899524109 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 49287.63712992406 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 69346.98483684243 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 69246.10965036259 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 69157.38340046618 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 55087.2738129776 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 54972.1404700689 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 54933.072042239044 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 50817.71896300781 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 50692.06499129964 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 50622.01575770202 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 49096.53813355052 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 48975.00172932169 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 48910.8377325177 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 48210.167994861986 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 48063.95167813468 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 48063.1598540099 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 56643.65751958504 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 56638.70897051755 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 56756.87901312662 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 52941.193657334254 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 52968.71153459272 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 52948.052012071166 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 51670.73455228414 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 51584.25547567616 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 51442.654052709804 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 50710.25087542477 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 50617.929290811706 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 50461.33619123916 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 50088.47358160905 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 50048.690794106275 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 49884.47049755828 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 53478.8249580028 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 53563.867090377156 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 53490.233779444236 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 50505.855993851925 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 50540.68749532892 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 50355.65286230942 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 49442.40357448067 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 49347.31881939261 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 49176.871564287896 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 48702.61664039466 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 48625.53126938557 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 48428.23187042128 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 48290.52474675331 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 48220.97961124836 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 47987.563385975714 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 51168.35780645146 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 51165.55448080625 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 51138.562558587444 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 48917.23309615767 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 48696.697186598576 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 48677.913137468015 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 48081.43714478123 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 47792.206483022856 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 47722.05986388598 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47463.74258072041 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 47234.81162838035 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 47159.62735343032 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47153.94253003243 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46860.45643917165 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46843.7842080947 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 49555.029942132816 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 49488.30074585889 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 49474.34187069707 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47766.3052843888 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 47465.33673886574 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 47509.28111155773 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47198.27486050655 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46896.159882413915 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46859.74971077103 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46709.91213702336 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46548.74167796883 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46508.81435197118 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46517.00512331959 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46413.30420835691 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46321.18415434657 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48498.97173268144 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 48284.96150488144 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 48120.51717375881 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47064.468208326594 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 46799.08585466407 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46685.78573095914 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 46644.71494640078 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46469.56280565219 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46220.32780010173 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46437.46045393847 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46256.11359529085 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46009.97450585939 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46304.37743590971 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46170.599851258645 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 45894.951504220866 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 53039.91786472084 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 53142.102888657035 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 52882.904604306525 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 50914.40790419537 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 50967.53250471975 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 50523.7498432217 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 50022.95889061943 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 49951.5056655085 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 49600.2107220005 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 49484.28034282455 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 49367.16857163498 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 48982.20581473615 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 49169.508963700726 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 49093.50480423424 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 48704.1861652826 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 50824.605545287326 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 50643.43594346932 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 50375.43856660762 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 49149.821120343426 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 49045.76633746811 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 48634.34117246021 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 48386.617639758755 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 48297.2556925338 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 47759.7314749598 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47876.68493440669 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 47938.729476334855 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 47348.05056597645 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47700.68661428995 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 47783.50286130768 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 47130.59227972216 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48947.75318299233 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 48937.10292632345 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 48779.054566948755 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47738.01495062826 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 47669.504207503334 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 47534.466847106276 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47293.9126043489 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 47134.425255222566 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 47133.86268651049 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47070.39143091337 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46909.021821466034 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46922.62981248476 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46945.90526410926 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46861.371721403106 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46847.156648851174 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48028.49912258934 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 47812.62944459785 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 47568.835258144005 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47313.75518124194 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 46854.109963079085 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46799.77881951258 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47046.744097926465 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46630.589777058696 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46558.23203047416 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47054.15273613069 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46566.37261128946 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46435.22986992221 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46992.20035688168 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46522.25198059194 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46463.97587512655 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 47304.23096716926 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 47196.413333617245 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 47124.033083080634 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 46887.16662612572 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 46670.74598083421 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46647.09925713516 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 46774.296650855824 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46478.48982724845 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46461.040848992714 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46747.666351120846 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46501.68260224267 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46456.82658684932 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46799.108152333356 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46504.05766127744 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46453.941225746385 {'xgb__colsample_bytree': 0.7, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 78738.41111070155 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 78742.5501208925 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 78814.08809407905 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 66523.64301558593 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 66594.14842684731 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 66678.70533454021 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 61150.30773006595 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 61169.563793528054 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 61266.426754914246 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 58344.90772687229 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 58429.59447714618 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 58508.317755279124 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 56565.561702602194 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 56624.31614976759 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 56801.31925128335 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 75353.23313697442 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 75368.75844978505 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 75395.96124434033 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 62327.2184488145 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 62375.96521112918 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 62419.07964255903 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 57220.12002538891 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 57268.930571518606 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 57377.614649259776 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 54668.472628031705 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 54774.47137161671 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 54798.64903254832 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 53153.7687190679 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 53271.247465942906 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 53293.46558344973 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 72470.33097255931 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 72484.95288087236 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 72529.77036046694 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 59049.48228173645 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 59114.824094431475 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 59202.57683718786 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 54441.18563249398 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 54419.88593101561 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 54515.72212148053 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 52188.21155304763 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 52230.92410436947 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 52374.00764780053 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 50966.126223899744 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 50955.72310821803 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 51076.066301302955 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 70226.62564101203 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 70133.4701793907 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 70139.672520145 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 56756.712243610986 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 56668.500108066175 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 56670.665643144486 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 52450.53395944386 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 52294.30959115431 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 52378.3955330233 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 50516.00817671943 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 50452.41896038158 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 50481.045196840234 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 49459.14583707677 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 49370.32605769389 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 49390.86446927185 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 68570.59886649875 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 68533.13999712733 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 68444.56090238695 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 55013.02617000178 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 54983.74937030033 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 54953.09518498283 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 50969.79826744685 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 50934.29350828664 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 50947.05295234568 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 49294.84715391671 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 49321.26999862287 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 49283.591424669125 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 48370.38774185629 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 48344.09900210963 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 48317.708740376314 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 56490.5509545779 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 56758.24781218853 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 56606.3883016352 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 52895.601378959786 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 53108.03951837705 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 52906.097492651395 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 51575.405112515306 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 51542.49080196699 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 51345.53891475364 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 50587.9768859479 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 50592.21503911802 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 50431.58447436695 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 49994.07240317407 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 49990.59461393817 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 49786.48945811048 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 53100.36629717102 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 53164.49806099968 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 53083.05519589351 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 50376.59153861369 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 50276.02440325796 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 50254.82279482562 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 49283.28011131702 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 49110.214966229985 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 48974.46630351976 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 48419.85026720467 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 48377.42839504865 {'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# ...
# 47157.573343362914 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47118.39697265031 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46859.49073527201 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46772.249831005625 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 49705.27521512802 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 49473.28970795256 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 49521.85082351299 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47788.67402622236 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 47559.440789122644 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 47732.88340318617 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47085.242141230905 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46830.87788006921 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46987.972003646246 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46733.30752668908 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46488.46606877616 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46615.54385620978 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46538.492750487334 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46298.78700712628 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46394.465139591244 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48478.623894743556 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 48395.93941194685 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 48351.93475788516 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47021.576886821116 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 47103.89572752493 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46956.22806832955 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 46571.38735840043 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46619.51407396993 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46483.76083541 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46365.55392167869 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46422.30875554591 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46305.27592866077 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46231.59569843448 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46303.71650817637 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46225.66790449482 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.05, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 53037.17068433654 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 53063.89045200803 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 52916.5304275992 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 50831.77635016861 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 50686.655661690485 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 50530.095461740835 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 49843.954962021024 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 49727.26160658193 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 49376.168326298815 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 49299.94388374579 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 49147.108026283386 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 48771.661972251735 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 48858.45740142026 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 48862.03162484565 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 48395.14041152836 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 50338.02867226475 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 50234.308578853495 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 50132.62264954116 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 48966.01569696571 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 48400.369051571804 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 48417.70112216139 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 48455.17900099823 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 47703.15168867405 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 47702.61920074608 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 48104.10821806927 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 47436.547353234855 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 47326.37462743449 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47806.46242387003 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 47236.5720716355 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 47208.65763705512 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48959.39265764858 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 48711.80225131731 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 48717.575240060614 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47923.527575296066 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 47375.64504181468 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 47321.292049986296 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47401.65961749429 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46883.87279805246 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46785.410838763484 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47221.021921772444 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46714.65795431805 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46604.18612851503 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47156.985297142026 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46629.076642833796 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46454.118332928105 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 5, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 48166.477758278415 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 47848.5730503172 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 47717.22307696062 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47324.85022817352 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 46928.663244664116 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46782.98988989568 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 47033.37003517947 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46707.8986242215 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46634.98132680115 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 46997.904943373636 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46629.97842850075 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46580.948985500814 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 46921.104313910495 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46639.20618260533 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46514.0724218692 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}
# 47509.1112073875 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.7}
# 47351.83835873483 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.8}
# 47484.61836287344 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 100, 'xgb__subsample': 0.9}
# 47014.80655389501 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.7}
# 46759.99302996356 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.8}
# 46932.97909534724 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 200, 'xgb__subsample': 0.9}
# 46979.29634138057 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.7}
# 46599.43018191813 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.8}
# 46841.14072895259 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 300, 'xgb__subsample': 0.9}
# 47030.32315559596 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.7}
# 46585.33507166689 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.8}
# 46817.4838346711 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 400, 'xgb__subsample': 0.9}
# 47042.36978546567 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.7}
# 46574.059751125234 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.8}
# 46811.35440432947 {'xgb__colsample_bytree': 0.9, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 7, 'xgb__n_estimators': 500, 'xgb__subsample': 0.9}

# %%
# let's look at the feature importances of the best estimator
final_model = grid_search.best_estimator_
xg_boost_model = final_model.named_steps['xgb']

# %%
final_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('attributes_adder',
#                                                                    CombinedAttribuesAdder()),
#                                                                   ('log_transformer',
#                                                                    LogTransformer(columns_to_log_transform=[3,
#                                                                                                             4,
#                                                                                                             5,
#                                                                                                             6])),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_b...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=7, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=500, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
xg_boost_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
feature_importances = xg_boost_model.feature_importances_
feature_importances
# Out:
# array([0.02949548, 0.03075471, 0.01521001, 0.00594857, 0.00793913,
#        0.00754104, 0.00725201, 0.1305858 , 0.04291394, 0.03582556,
#        0.05452032, 0.48419818, 0.02880814, 0.0637686 , 0.0552385 ],
#       dtype=float32)

# %%
num_features = numerical_features + ['rooms_per_household', 'population_per_household']
cat_feature_names = final_model.named_steps['preprocessor'].transformers_[1][1].get_feature_names_out(categorical_features)
feature_names = num_features + list(cat_feature_names)

feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

feature_importance_df
# Out:
#                        Feature  Importance
# 11      ocean_proximity_INLAND    0.484198
# 7                median_income    0.130586
# 13    ocean_proximity_NEAR BAY    0.063769
# 14  ocean_proximity_NEAR OCEAN    0.055238
# 10   ocean_proximity_<1H OCEAN    0.054520
# 8          rooms_per_household    0.042914
# 9     population_per_household    0.035826
# 1                     latitude    0.030755
# 0                    longitude    0.029495
# 12      ocean_proximity_ISLAND    0.028808
# 2           housing_median_age    0.015210
# 4               total_bedrooms    0.007939
# 5                   population    0.007541
# 6                   households    0.007252
# 3                  total_rooms    0.005949

# %% [markdown]
# ### Evaluation on test set

# %%
predictons_final = final_model.predict(testing_X)

# %%
mape = mean_absolute_percentage_error(testing_y, predictons_final)
mse = mean_squared_error(testing_y, predictons_final)
print(f'Mean Absolution % Error: {mape}, Root Mean Squared Error: {np.sqrt(mse)}')
# Out:
# Mean Absolution % Error: 0.15844195018128124, Root Mean Squared Error: 42119.337569170275

# %% [markdown]
# # Observations:
# <li> Whether the house is in proximity to ocean_proximity[inland] is the number one predictor of housing prices </li>
# <li> Median income contributes to about 13% importance in house price prediction </li>
# <li> The model could be used as a tool to predict house prices with an average error of + or - 42k USD </li>
